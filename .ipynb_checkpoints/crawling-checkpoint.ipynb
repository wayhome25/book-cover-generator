# %%
import requests
html = requests.get('https://dev.to/rly').text

# %%
html
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n  <meta charset="utf-8">\n  <title>O RLY Parody Book Generator for Slack</title>\n    <meta name="last-updated" content="2017-12-09 16:11:03 +0000">\n    <meta name="user-signed-in" content="false">\n        <link rel="stylesheet" media="all" href="https://practicaldev-herokuapp-com.freetls.fastly.net/assets/application-f4a5b0655573237dd08c294e1b1d25af451bf9788fef85e1a079b452b485d074.css" />\n\n      <link rel="stylesheet" media="all" href="https://practicaldev-herokuapp-com.freetls.fastly.net/assets/application-f4a5b0655573237dd08c294e1b1d25af451bf9788fef85e1a079b452b485d074.css" />\n        <link href=\'https://fonts.googleapis.com/css?family=Roboto\' rel=\'stylesheet\' type=\'text/css\'>\n        <script src="https://practicaldev-herokuapp-com.freetls.fastly.net/assets/application-f6081335b7e2d7bafa2abd77ccb6ed17b390457ddd266074a7f08258dacf629a.js"></script>\n\n    \n<link rel="canonical" href="https://dev.to/rly"/>\n<meta name="descript
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>O RLY Parody Book Generator for Slack</title>
# <meta content="2017-12-09 16:11:03 +0000" name="last-updated"/>
# <meta content="false" name="user-signed-in"/>
# <link href="https://practicaldev-herokuapp-com.freetls.fastly.net/assets/application-f4a5b0655573237dd08c294e1b1d25af451bf9788fef85e1a079b452b485d074.css" media="all" rel="stylesheet"/>
# <link href="https://practicaldev-herokuapp-com.freetls.fastly.net/assets/application-f4a5b0655573237dd08c294e1b1d25af451bf9788fef85e1a079b452b485d074.css" media="all" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet" type="text/css"/>
# <script src="https://practicaldev-herokuapp-com.freetls.fastly.net/assets/application-f6081335b7e2d7bafa2abd77ccb6ed17b390457ddd266074a7f08258dacf629a.js"></script>
# <link href="https://dev.to/rly" rel="canonical">
# ...

# %%
soup.select('.color')
# Out:
# [<div class="color" style="background-color:rgba(85,19,93,255)">0</div>,
#  <div class="color" style="background-color:rgba(113,112,110,255)">1</div>,
#  <div class="color" style="background-color:rgba(128,27,42,255)">2</div>,
#  <div class="color" style="background-color:rgba(184,7,33,255)">3</div>,
#  <div class="color" style="background-color:rgba(101,22,28,255)">4</div>,
#  <div class="color" style="background-color:rgba(80,61,189,255)">5</div>,
#  <div class="color" style="background-color:rgba(225,17,5,255)">6</div>,
#  <div class="color" style="background-color:rgba(6,123,176,255)">7</div>,
#  <div class="color" style="background-color:rgba(247,181,0,255)">8</div>,
#  <div class="color" style="background-color:rgba(0,15,118,255)">9</div>,
#  <div class="color" style="background-color:rgba(168,0,155,255)">10</div>,
#  <div class="color" style="background-color:rgba(0,132,69,255)">11</div>,
#  <div class="color" style="background-color:rgba(0,153,157,255)">12</div>,
# ...

# %%
import re
for tag in soup.select('.color'):
    code = tuple(map(int, re.findall(r'\d+', tag['style'])))
    print(code)
# Out:
# (85, 19, 93, 255)
# (113, 112, 110, 255)
# (128, 27, 42, 255)
# (184, 7, 33, 255)
# (101, 22, 28, 255)
# (80, 61, 189, 255)
# (225, 17, 5, 255)
# (6, 123, 176, 255)
# (247, 181, 0, 255)
# (0, 15, 118, 255)
# (168, 0, 155, 255)
# (0, 132, 69, 255)
# (0, 153, 157, 255)
# (1, 66, 132, 255)
# (177, 0, 52, 255)
# (55, 142, 25, 255)
# (133, 152, 0, 255)

# %%
for tag in soup.select('.animal'):
    code = tuple(map(int, re.findall(r'\d+', tag['style'])))
    print(code)
# Out:
# <function SRE_Match.start>
